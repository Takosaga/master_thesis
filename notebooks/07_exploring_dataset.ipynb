# %% [markdown]
# # Exploring Dataset
#
# This is a notebook to explore the dataset created

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import dtale
import os
from master_thesis.config import PROCESSED_DATA_DIR, load_dataframe_from_pickle

# %%
annotated_and_targeted_hatespeech_df = load_dataframe_from_pickle(
    PROCESSED_DATA_DIR / "annotated_and_targeted_hatespeech.pkl"
)

display(annotated_and_targeted_hatespeech_df.head(5))
# Out:
#    id_new                                               text extracted_target  \
# 0       1  i dont think im getting my baby them white 9 h...           {none}
# 1       2  we cannot continue calling ourselves feminists...           {none}
# 2       3                      nawt yall niggers ignoring me           {race}
# 3       4  <user> i am bit confused coz chinese ppl can n...           {race}
# 4       5  this bitch in whataburger eating a burger with...   {gender, race}
#
#   label_hatespeech_binary_offensive_not_included  \
# 0                                 not_hatespeech
# 1                                 not_hatespeech
# 2                                 not_hatespeech
# 3                                     hatespeech
# 4                                     hatespeech
#
#   label_hatespeech_binary_offensive_included  \
# 0                                     normal
# 1                                     normal
# 2                                     normal
# ...

# %%
figures_dir = '../reports/figures/'

# %%
print(annotated_and_targeted_hatespeech_df.shape) 
print(annotated_and_targeted_hatespeech_df.info())
# Out:
# (65217, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65217 entries, 0 to 65216
# Data columns (total 11 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   id_new                                          65217 non-null  int64
#  1   text                                            65217 non-null  object
#  2   extracted_target                                65217 non-null  object
#  3   label_hatespeech_binary_offensive_not_included  65217 non-null  category
#  4   label_hatespeech_binary_offensive_included      65217 non-null  category
#  5   label_normal_offensive_hatespeech               65217 non-null  category
#  6   platform                                        65217 non-null  category
#  7   original_dataset_title                          65217 non-null  category
#  8   original_id                                     65217 non-null  object
# ...

# %%
annotated_and_targeted_hatespeech_df.describe()
# Out:
#             id_new
# count  65217.00000
# mean   32609.00000
# std    18826.67059
# min        1.00000
# 25%    16305.00000
# 50%    32609.00000
# 75%    48913.00000
# max    65217.00000

# %%
annotated_and_targeted_hatespeech_df.isnull().sum()
# Out:
# id_new                                            0
# text                                              0
# extracted_target                                  0
# label_hatespeech_binary_offensive_not_included    0
# label_hatespeech_binary_offensive_included        0
# label_normal_offensive_hatespeech                 0
# platform                                          0
# original_dataset_title                            0
# original_id                                       0
# original_label                                    0
# original_target                                   0
# dtype: int64

# %%
annotated_and_targeted_hatespeech_df.dtypes
# Out:
# id_new                                               int64
# text                                                object
# extracted_target                                    object
# label_hatespeech_binary_offensive_not_included    category
# label_hatespeech_binary_offensive_included        category
# label_normal_offensive_hatespeech                 category
# platform                                          category
# original_dataset_title                            category
# original_id                                         object
# original_label                                    category
# original_target                                     object
# dtype: object

# %%
columns = ['extracted_target', 'label_hatespeech_binary_offensive_not_included', 'label_hatespeech_binary_offensive_included'
          , 'label_normal_offensive_hatespeech', 'platform', 'original_dataset_title']

# %%
for col in columns:
    print(f'\nColumn: {col}')
    print(annotated_and_targeted_hatespeech_df[col].value_counts())
# Out:
# Column: extracted_target
# extracted_target
# {gender}                                         11085
# {race}                                            9798
# {none}                                            7685
# {religion}                                        7219
# {sexuality}                                       5855
#                                                  ...
# {disability, gender, race, religion}                 1
# {race, sexuality, other, gender, nationality}        1
# {gender, sexuality, religion, disability}            1
# {gender, nationality, religion, other}               1
# {disability, nationality, race, other}               1
# Name: count, Length: 101, dtype: int64
#
# Column: label_hatespeech_binary_offensive_not_included
# label_hatespeech_binary_offensive_not_included
# not_hatespeech    50256
# hatespeech        14961
# Name: count, dtype: int64
#
# Column: label_hatespeech_binary_offensive_included
# label_hatespeech_binary_offensive_included
# ...

# %%
for col in columns:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=col, data=annotated_and_targeted_hatespeech_df, order=annotated_and_targeted_hatespeech_df[col].value_counts().index, palette="viridis")
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# /tmp/ipykernel_71855/2957868854.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_71855/2957868854.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_71855/2957868854.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_71855/2957868854.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_71855/2957868854.py:3: FutureWarning:
#
#
#
# ...

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='label_hatespeech_binary_offensive_included', data=annotated_and_targeted_hatespeech_df, order=annotated_and_targeted_hatespeech_df['label_hatespeech_binary_offensive_included'].value_counts().index, palette="viridis")
plt.title(f"Distribution of label_hatespeech_binary_offensive_included")
plt.xticks()

plt.savefig(os.path.join(figures_dir, 'distribution_of_hatespeech.svg'), format='svg')

plt.show()
# Out:
# /tmp/ipykernel_71855/1503835618.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
col = 'platform'
plt.figure(figsize=(8, 4))
sns.countplot(x=col, data=annotated_and_targeted_hatespeech_df, order=annotated_and_targeted_hatespeech_df[col].value_counts().index, palette="viridis")
plt.title(f"Distribution of {col}")
plt.xticks()

plt.savefig(os.path.join(figures_dir, 'distribution_of_platform.svg'), format='svg')


plt.show()
# Out:
# /tmp/ipykernel_71855/2145823924.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
d = dtale.show(annotated_and_targeted_hatespeech_df)
d.open_browser()

# %% [markdown]
# ### Targeted Groups from Sets
#
# Adjusting extracted targets to if the set contain a targeted group then it counts towars the total count of each targeted group

# %%
# Explode the 'extracted_target' column (convert sets into individual rows)
exploded_df = annotated_and_targeted_hatespeech_df.explode('extracted_target')

# Count the occurrences of each target group
target_counts = exploded_df['extracted_target'].value_counts()

# Plot the counts
plt.figure(figsize=(10, 6))
sns.barplot(x=target_counts.index, y=target_counts.values, palette="viridis")
plt.title("Count of Each Target Group (multiple targets in set)")
plt.xlabel("Target Group")
plt.ylabel("Count")
# plt.xticks(rotation=45)

plt.savefig(os.path.join(figures_dir, 'count_of_each_target_group(multiple_targets_in_set).svg'), format='svg')

plt.show()
# Out:
# /tmp/ipykernel_71855/406686302.py:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
print(target_counts)
print('Total of target counts for singles:',sum(target_counts))
# Out:
# extracted_target
# gender         17506
# race           17317
# nationality    11966
# religion       10929
# sexuality      10217
# none            7685
# other           4423
# disability      2885
# Name: count, dtype: int64
# Total of target counts for singles: 82928

# %% [markdown]
# ### Single Targeted Groups From Sets
#
# From sets that only target one group

# %%
# Filter rows where 'extracted_target' has only one element in the set
single_target_df = annotated_and_targeted_hatespeech_df[
    annotated_and_targeted_hatespeech_df['extracted_target'].apply(lambda x: len(x) == 1)
]

single_target_df['extracted_target'] = single_target_df['extracted_target'].apply(lambda x: list(x)[0])

# Count the occurrences of each target group
target_counts = single_target_df['extracted_target'].value_counts()
# Out:
# /tmp/ipykernel_71855/3123769697.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
single_target_df
# Out:
#        id_new                                               text  \
# 0           1  i dont think im getting my baby them white 9 h...
# 1           2  we cannot continue calling ourselves feminists...
# 2           3                      nawt yall niggers ignoring me
# 3           4  <user> i am bit confused coz chinese ppl can n...
# 5           6  laura loomer raped me while screaming at me in...
# ...       ...                                                ...
# 65204   65205  After bantering about the Leicester Chopper cr...
# 65210   65211  @user I wish I\u2019d never laid eyes on the c...
# 65211   65212  @user The helpers are losing the battle and so...
# 65212   65213  @user @user @user Maybe but @user who lied abo...
# 65213   65214              @user @user You\u2019re a retard :) x
#
#       extracted_target label_hatespeech_binary_offensive_not_included  \
# 0                 none                                 not_hatespeech
# ...

# %%
print(target_counts)
print('Total of target counts for singles:',sum(target_counts))
# Out:
# extracted_target
# gender         11085
# race            9798
# none            7685
# religion        7219
# sexuality       5855
# nationality     5254
# disability      1523
# other           1478
# Name: count, dtype: int64
# Total of target counts for singles: 49897

# %%
# Plot the counts
plt.figure(figsize=(10, 6))
sns.barplot(x=target_counts.index, y=target_counts.values, palette="cividis")
plt.title("Count of Each Target Group (single target in set)")
plt.xlabel("Target Group")
plt.ylabel("Count")
#plt.xticks(rotation=45)

plt.savefig(os.path.join(figures_dir, 'count_of_each_target_group(single_target_in_set).svg'), format='svg')

plt.show()
# Out:
# /tmp/ipykernel_71855/2735042643.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
for col in columns:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=col, data=single_target_df, order=single_target_df[col].value_counts().index, palette="viridis")
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=45)
    plt.show()
# Out:
# /tmp/ipykernel_106441/97238798.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_106441/97238798.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_106441/97238798.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_106441/97238798.py:3: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_106441/97238798.py:3: FutureWarning:
#
#
#
# ...

# %%
# Group by 'original_dataset' or 'platform' and create separate plots
grouping_columns = ['original_dataset_title', 'platform']  # Replace with the actual column names in your DataFrame

for group_col in grouping_columns:
    grouped = single_target_df.groupby(group_col)
    
    for group_name, group_data in grouped:
        plt.figure(figsize=(8, 4))
        sns.countplot(
            x='extracted_target',  # Replace with the column you want to count
            data=group_data,
            order=group_data['extracted_target'].value_counts().index,
            palette="viridis"
        )
        plt.title(f"Distribution of extracted_target for {group_col}: {group_name}")
        plt.xticks(rotation=45)
        plt.xlabel("Target Group")
        plt.ylabel("Count")
        plt.show()
# Out:
# /tmp/ipykernel_106441/1271799839.py:5: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipykernel_106441/1271799839.py:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_106441/1271799839.py:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_106441/1271799839.py:9: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# ...

# %%
different_hatespeech_labeling = ['label_hatespeech_binary_offensive_not_included', 'label_hatespeech_binary_offensive_included'
          , 'label_normal_offensive_hatespeech']

# %%
for label in different_hatespeech_labeling:
    for group_col in grouping_columns:
        grouped = single_target_df.groupby(group_col)
        
        for group_name, group_data in grouped:
            plt.figure(figsize=(8, 4))
            sns.countplot(
                x=label,  # Replace with the column you want to count
                data=group_data,
                order=group_data[label].value_counts().index,
                palette="viridis"
            )
            plt.title(f"Distribution of {label} for {group_col}: {group_name}")
            plt.xticks(rotation=45)
            plt.xlabel("Target Group")
            plt.ylabel("Count")
            plt.show()
# Out:
# /tmp/ipykernel_106441/1060328268.py:3: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#
# /tmp/ipykernel_106441/1060328268.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_106441/1060328268.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# /tmp/ipykernel_106441/1060328268.py:7: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
# ...
